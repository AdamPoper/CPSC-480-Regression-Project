# %%
# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os
import pandas as pd

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
import pandas as pd

carsdf=pd.read_csv("used_car_sales.csv")

# %%
carsdf.head()
# Out:
#        ID  pricesold  yearsold zipcode  Mileage               Make  \
# 0  137178       7500      2020   786**    84430               Ford
# 1   96705      15000      2019   81006        0  Replica/Kit Makes
# 2  119660       8750      2020   33449    55000             Jaguar
# 3   80773      11600      2019    7852    97200               Ford
# 4   64287      44000      2019    7728    40703            Porsche
#
#                 Model  Year           Trim                   Engine  \
# 0             Mustang  1988             LX              5.0L Gas V8
# 1  Jaguar Beck Lister  1958            NaN        383 Fuel injected
# 2                 XJS  1995  2+2 Cabriolet  4.0L In-Line 6 Cylinder
# 3             Mustang  1968          Stock           289 cu. in. V8
# 4                 911  2002     Turbo X-50                     3.6L
#
#       BodyType  NumCylinders DriveType
# 0        Sedan             0       RWD
# 1  Convertible             8       RWD
# ...

# %%
carsdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122144 entries, 0 to 122143
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   ID            122144 non-null  int64
#  1   pricesold     122144 non-null  int64
#  2   yearsold      122144 non-null  int64
#  3   zipcode       121235 non-null  object
#  4   Mileage       122144 non-null  int64
#  5   Make          122144 non-null  object
#  6   Model         121571 non-null  object
#  7   Year          122144 non-null  int64
#  8   Trim          73220 non-null   object
#  9   Engine        95046 non-null   object
#  10  BodyType      101358 non-null  object
#  11  NumCylinders  122144 non-null  int64
#  12  DriveType     97293 non-null   object
# dtypes: int64(6), object(7)
# memory usage: 12.1+ MB

# %%
carsdf.size
# Out:
# 1587872

# %%
carsdf.describe()
# Out:
#                   ID      pricesold       yearsold       Mileage  \
# count  122144.000000  122144.000000  122144.000000  1.221440e+05
# mean    85094.212397   10808.560715    2019.375467  1.404291e+06
# std     47786.970812   13987.295760       0.503671  3.335593e+07
# min         1.000000       0.000000    2018.000000  0.000000e+00
# 25%     44547.250000    2950.000000    2019.000000  4.479225e+04
# 50%     85555.500000    6500.000000    2019.000000  9.000000e+04
# 75%    127078.500000   13800.000000    2020.000000  1.402000e+05
# max    165801.000000  404990.000000    2020.000000  1.235669e+09
#
#                Year  NumCylinders
# count  1.221440e+05  1.221440e+05
# mean   3.959362e+03  1.758655e+04
# std    1.984514e+05  6.144603e+06
# min    0.000000e+00  0.000000e+00
# 25%    1.977000e+03  4.000000e+00
# 50%    2.000000e+03  6.000000e+00
# 75%    2.008000e+03  8.000000e+00
# max    2.014000e+07  2.147484e+09

# %%
cars_df = carsdf.drop(columns=['ID', 'yearsold', 'NumCylinders', 'Engine', 'Trim', 'zipcode', 'DriveType', 'BodyType', 'Model'])
cars_df
# Out:
#         pricesold  Mileage               Make  Year
# 0            7500    84430               Ford  1988
# 1           15000        0  Replica/Kit Makes  1958
# 2            8750    55000             Jaguar  1995
# 3           11600    97200               Ford  1968
# 4           44000    40703            Porsche  2002
# ...           ...      ...                ...   ...
# 122139       4200   102700               Ford  1977
# 122140       6500   128000               Ford  2012
# 122141       2000    50000               Ford  1978
# 122142       2280   164337                BMW  2000
# 122143       5000   163111             Nissan  1990
#
# [122144 rows x 4 columns]

# %%
cars_df.shape
# Out:
# (122144, 4)

# %%
cars_df = cars_df.dropna()
cars_df
# Out:
#         pricesold  Mileage               Make  Year
# 0            7500    84430               Ford  1988
# 1           15000        0  Replica/Kit Makes  1958
# 2            8750    55000             Jaguar  1995
# 3           11600    97200               Ford  1968
# 4           44000    40703            Porsche  2002
# ...           ...      ...                ...   ...
# 122139       4200   102700               Ford  1977
# 122140       6500   128000               Ford  2012
# 122141       2000    50000               Ford  1978
# 122142       2280   164337                BMW  2000
# 122143       5000   163111             Nissan  1990
#
# [122144 rows x 4 columns]

# %%
cars_df.shape
# Out:
# (122144, 4)

# %%
cars_df = cars_df[cars_df['Mileage'] >= 5000]
cars_df = cars_df[cars_df['Mileage'] <= 500000]
cars_df
# Out:
#         pricesold  Mileage     Make  Year
# 0            7500    84430     Ford  1988
# 2            8750    55000   Jaguar  1995
# 3           11600    97200     Ford  1968
# 4           44000    40703  Porsche  2002
# 5             950    71300  Mercury  1965
# ...           ...      ...      ...   ...
# 122139       4200   102700     Ford  1977
# 122140       6500   128000     Ford  2012
# 122141       2000    50000     Ford  1978
# 122142       2280   164337      BMW  2000
# 122143       5000   163111   Nissan  1990
#
# [111050 rows x 4 columns]

# %%
cars_df.loc[cars_df['Make'].str.contains('Toyota'), 'Make']='Toyota'
cars_df.loc[cars_df['Make'].str.contains('Honda'), 'Make']='Honda'
cars_df.loc[cars_df['Make'].str.contains('Chevrolet'), 'Make']='Chevrolet'
cars_df.loc[cars_df['Make'].str.contains('Ford'), 'Make']='Ford'
cars_df.loc[cars_df['Make'].str.contains('Mercedes'), 'Make']='Mercedes Benz'
cars_df.loc[cars_df['Make'].str.contains('Jeep'), 'Make']='Jeep'
cars_df.loc[cars_df['Make'].str.contains('BMW'), 'Make']='BMW'
cars_df.loc[cars_df['Make'].str.contains('Porsche'), 'Make']='Porsche'
cars_df.loc[cars_df['Make'].str.contains('Subaru'), 'Make']='Subaru'
cars_df.loc[cars_df['Make'].str.contains('Nissan'), 'Make']='Nissan'

# %%
cars_df = cars_df[cars_df['Year'] >= 1900]
cars_df = cars_df[cars_df['Year'] <= 2021]
cars_df = cars_df[cars_df['pricesold'] >= 100]
cars_df=cars_df[cars_df['Make'].str.contains('Toyota|Honda|Chevrolet|Ford|Mercedes Benz|Jeep|BMW|Porsche|Subaru|Nissan')]
cars_df
# Out:
#         pricesold  Mileage     Make  Year
# 0            7500    84430     Ford  1988
# 3           11600    97200     Ford  1968
# 4           44000    40703  Porsche  2002
# 8            1330   167000    Honda  2001
# 10          20000    51674     Jeep  2015
# ...           ...      ...      ...   ...
# 122139       4200   102700     Ford  1977
# 122140       6500   128000     Ford  2012
# 122141       2000    50000     Ford  1978
# 122142       2280   164337      BMW  2000
# 122143       5000   163111   Nissan  1990
#
# [68150 rows x 4 columns]

# %%
cars_df["Make"].value_counts()
# Out:
# Ford             19395
# Chevrolet        17886
# Toyota            6455
# Mercedes Benz     6053
# BMW               5008
# Jeep              4212
# Honda             3344
# Nissan            2440
# Porsche           2071
# Subaru            1286
# Name: Make, dtype: int64

# %%
cars_df = cars_df[cars_df['Mileage'] >= 5000]
cars_df = cars_df[cars_df['Mileage'] <= 500000]

# %%
carsdf['Mileage'].value_counts()
# Out:
# 0         2957
# 100000    1513
# 99999     1034
# 999999     865
# 1          541
#           ...
# 95481        1
# 204358       1
# 89340        1
# 218365       1
# 133119       1
# Name: Mileage, Length: 60843, dtype: int64

# %%
from matplotlib import pyplot as plt
import numpy as np
fig,ax = plt.subplots(1,1)
a = cars_df["Mileage"]
ax.hist(a, bins = [0,40000,80000,120000,160000,200000,240000,280000,320000,360000,400000])
ax.set_title("Milage")
ax.set_xticks([0,40000,80000,120000,160000,200000,240000,280000,320000,360000,400000])
ax.set_xlabel('marks')
ax.set_ylabel('Miles')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
fig,ax = plt.subplots(1,1)
a = cars_df["Year"]
ax.hist(a, bins = [1950,1960,1970,1980,1990,2000,2010,2020])
ax.set_title("YearMade")
ax.set_xticks([1950,1960,1970,1980,1990,2000,2010,2020])
ax.set_xlabel('marks')
ax.set_ylabel('Year')
plt.show()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(cars_df, figsize=(12, 8))
# Out:
# array([[<AxesSubplot:xlabel='pricesold', ylabel='pricesold'>,
#         <AxesSubplot:xlabel='Mileage', ylabel='pricesold'>,
#         <AxesSubplot:xlabel='Year', ylabel='pricesold'>],
#        [<AxesSubplot:xlabel='pricesold', ylabel='Mileage'>,
#         <AxesSubplot:xlabel='Mileage', ylabel='Mileage'>,
#         <AxesSubplot:xlabel='Year', ylabel='Mileage'>],
#        [<AxesSubplot:xlabel='pricesold', ylabel='Year'>,
#         <AxesSubplot:xlabel='Mileage', ylabel='Year'>,
#         <AxesSubplot:xlabel='Year', ylabel='Year'>]], dtype=object)

# %%
x = cars_df[['Mileage', 'Year', 'Make']]
x
# Out:
#         Mileage  Year     Make
# 0         84430  1988     Ford
# 3         97200  1968     Ford
# 4         40703  2002  Porsche
# 8        167000  2001    Honda
# 10        51674  2015     Jeep
# ...         ...   ...      ...
# 122139   102700  1977     Ford
# 122140   128000  2012     Ford
# 122141    50000  1978     Ford
# 122142   164337  2000      BMW
# 122143   163111  1990   Nissan
#
# [68150 rows x 3 columns]

# %%
x=pd.get_dummies(data=x,drop_first=True)
x.head()
# Out:
#     Mileage  Year  Make_Chevrolet  Make_Ford  Make_Honda  Make_Jeep  \
# 0     84430  1988               0          1           0          0
# 3     97200  1968               0          1           0          0
# 4     40703  2002               0          0           0          0
# 8    167000  2001               0          0           1          0
# 10    51674  2015               0          0           0          1
#
#     Make_Mercedes Benz  Make_Nissan  Make_Porsche  Make_Subaru  Make_Toyota
# 0                    0            0             0            0            0
# 3                    0            0             0            0            0
# 4                    0            0             1            0            0
# 8                    0            0             0            0            0
# 10                   0            0             0            0            0

# %%
y=cars_df['pricesold']
y
# Out:
# 0          7500
# 3         11600
# 4         44000
# 8          1330
# 10        20000
#           ...
# 122139     4200
# 122140     6500
# 122141     2000
# 122142     2280
# 122143     5000
# Name: pricesold, Length: 68150, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=30)

# %%
len(x_train)
# Out:
# 54520

# %%
len(x_test)
# Out:
# 13630

# %%
x_test
# Out:
#         Mileage  Year  Make_Chevrolet  Make_Ford  Make_Honda  Make_Jeep  \
# 43423    123069  2004               0          0           0          1
# 58250     61000  1987               0          0           0          0
# 89523    123500  2009               1          0           0          0
# 62950    181662  1987               0          0           0          0
# 115192   162560  2008               1          0           0          0
# ...         ...   ...             ...        ...         ...        ...
# 29220    245000  2002               0          1           0          0
# 6584     140000  1988               1          0           0          0
# 64835     28972  2015               0          0           0          0
# 108274   108680  2005               0          0           0          1
# 3862      21260  2015               0          1           0          0
#
#         Make_Mercedes Benz  Make_Nissan  Make_Porsche  Make_Subaru  \
# ...

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error

pricesold_predictions = lin_reg.predict(x_test)
lin_mse = mean_squared_error(y_test, pricesold_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 10455.364716714768

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import cross_val_score
diabetes = datasets.load_diabetes()
X = diabetes.data[:150]
# Out:
# [0.33150734 0.08022311 0.03531764]

# %%
a = cars_df.data[:150]
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [-0.05637009, -0.04464164,  0.09295276, ...,  0.02545259,
#          0.02605609,  0.04034337],
#        [-0.06000263,  0.05068012,  0.01535029, ..., -0.00259226,
#         -0.03075121, -0.0010777 ],
#        [-0.04910502,  0.05068012, -0.00512814, ...,  0.07120998,
#          0.06123791, -0.03835666]])

# %%
from sklearn.model_selection import cross_val_score
lin_scores = cross_val_score(lin_reg, x_train,y_test,scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-dbe94bedd351> in <module>
#       1 from sklearn.model_selection import cross_val_score
# ----> 2 lin_scores = cross_val_score(lin_reg, x_train,y_test,scoring="neg_mean_squared_error", cv=10)
#       3 lin_rmse_scores = np.sqrt(-lin_scores)
#       4 display_scores(lin_rmse_scores)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
# ...
